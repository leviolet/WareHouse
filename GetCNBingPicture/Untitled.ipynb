# %%
import requests
import pyquery

def getOne(url: str):
    headers = {
        'user-agent': r"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36",
        'Accept-Charset': r"utf-8"
    }

    r = requests.get(url, headers=headers)
    if r.status_code >= 300:
        return -1

    s = r.content.decode('gbk')

    document = pyquery.PyQuery(s)
    p = document('#mainNewsContent > p:nth-child(6)')
    print(p.text())
    
for i in range(2,5):
    url = r"https://3gmfw.cn/article/html2/2020/03/31/519097" + f"_{i}" + ".html"
    getOne(url)
# Out:
# 为什么要学习中国近现代史？
#
# 1.根据2018年版《中国近现代史纲要》,中国的近代史,是从1840年开始到()结束。
#
# A、1919年
#
# B、1937年
#
# C、1949年
#
# D、1954年
#
# 答案：C
#
# 2.树立正确的历史观,需要自觉抵制历史虚无主义。()
#
# 答案：对
#
# 准确把握《中国近现代史纲要》的教学目的与要求
#
# 1.列宁全面论述帝国主义的专著是()。
#
# A、《资本论》
#
# B、《帝国主义是资本主义的最高阶段》
#
# C、《新教伦理与资本主义精神》
#
# D、《国富论》
#
# 答案：B
#
# 2.下面属于中国特色社会主义的四个自信的是()。
#
# A、道路自信
#
# B、理论自信
#
# C、制度自信
#
# D、道德自信
#
# 答案：ABC
#
# 怎样学好中国近现代史？
#
# 1.学好中国近代史,必须要做到()。
#
# A、阅读
#
# B、思考
#
# C、讨论
#
# D、实践
#
# 答案：ABCD
#
# 2.习近平曾说,“学习的敌人是自己的满足”。()
#
# 答案：错
#
# 鸦片战争前的中国与世界
#
# 1.以下哪一项,不属于中国封建社会的基本经济特征。()
#
# A、实行高度集权的封建君主专制制度
#
# B、封建地主土地所有制占主导地位
#
# C、以个体家庭为单位并与家庭手工业牢固结合的小农经济是中国封建社会的基本生产结构
#
# D、自给自足的自然经济始终占绝对优势
#
# 答案：AD
#
# 2.在鸦片战争前,中国封建社会由昌盛到衰落。()
#
# 答案：对
#
# 外国资本主义入侵与近代中国社会的半殖民地半封建性质
#
# 1.()是中国近代史上第一个不平等条约。
#
# A、《望厦条约》
#
# B、《黄埔条约》
#
# C、《南京条约》
#
# D、《北京条约》
#
# 答案：C
#
# 2.以下哪几项,属于半殖民地半封建中国社会的特征。()
#
# A、资本-帝国主义侵略势力日益成为支配中国的决定性力量
#
# B、中国封建势力日益衰败
#
# C、中国封建剥削制度的根基在广大地区内保持着
#
# D、中国新兴民族资本主义发展缓慢、力量薄弱
#
# 答案：ABCD
#
# 近代中国的主要矛盾和历史任务
#
# 1.近代以来的历史表明,改变中国半殖民地半封建社会制度,可通过()。
#
# A、教育救国
#
# B、工业救国
#
# C、改良主义
#
# D、进行反帝反封建的民主革命
#
# 答案：D
#
# 2.近代中国半殖民地半封建社会的矛盾中,资产阶级与地主阶级的矛盾是占支配地位的主要矛盾。()
#
# 答案：错
#
# 资本—帝国主义的军事侵略（一）
#
# 1.中日甲午战争发生于哪一年?()
#
# A、1860年
#
# B、1894年
#
# C、1900年
#
# D、1936年
#
# 答案：B
#
# 2.“旅顺大屠杀惨案”的制造者是哪个国家?()
#
# A、德国
# 为什么要学习中国近现代史？
#
# 1.根据2018年版《中国近现代史纲要》,中国的近代史,是从1840年开始到()结束。
#
# A、1919年
#
# B、1937年
#
# C、1949年
#
# D、1954年
#
# 答案：C
#
# 2.树立正确的历史观,需要自觉抵制历史虚无主义。()
#
# 答案：对
#
# 准确把握《中国近现代史纲要》的教学目的与要求
#
# 1.列宁全面论述帝国主义的专著是()。
#
# A、《资本论》
#
# B、《帝国主义是资本主义的最高阶段》
#
# C、《新教伦理与资本主义精神》
#
# D、《国富论》
#
# 答案：B
#
# 2.下面属于中国特色社会主义的四个自信的是()。
#
# A、道路自信
#
# B、理论自信
#
# C、制度自信
#
# D、道德自信
#
# 答案：ABC
#
# 怎样学好中国近现代史？
#
# 1.学好中国近代史,必须要做到()。
#
# A、阅读
#
# B、思考
#
# C、讨论
#
# D、实践
#
# 答案：ABCD
#
# 2.习近平曾说,“学习的敌人是自己的满足”。()
#
# 答案：错
#
# 鸦片战争前的中国与世界
#
# 1.以下哪一项,不属于中国封建社会的基本经济特征。()
#
# A、实行高度集权的封建君主专制制度
#
# B、封建地主土地所有制占主导地位
#
# C、以个体家庭为单位并与家庭手工业牢固结合的小农经济是中国封建社会的基本生产结构
#
# D、自给自足的自然经济始终占绝对优势
#
# 答案：AD
#
# 2.在鸦片战争前,中国封建社会由昌盛到衰落。()
#
# 答案：对
#
# 外国资本主义入侵与近代中国社会的半殖民地半封建性质
#
# 1.()是中国近代史上第一个不平等条约。
#
# A、《望厦条约》
#
# B、《黄埔条约》
#
# C、《南京条约》
#
# D、《北京条约》
#
# 答案：C
#
# 2.以下哪几项,属于半殖民地半封建中国社会的特征。()
#
# A、资本-帝国主义侵略势力日益成为支配中国的决定性力量
#
# B、中国封建势力日益衰败
#
# C、中国封建剥削制度的根基在广大地区内保持着
#
# D、中国新兴民族资本主义发展缓慢、力量薄弱
#
# 答案：ABCD
#
# 近代中国的主要矛盾和历史任务
#
# 1.近代以来的历史表明,改变中国半殖民地半封建社会制度,可通过()。
#
# A、教育救国
#
# B、工业救国
#
# C、改良主义
#
# D、进行反帝反封建的民主革命
#
# 答案：D
#
# 2.近代中国半殖民地半封建社会的矛盾中,资产阶级与地主阶级的矛盾是占支配地位的主要矛盾。()
#
# 答案：错
#
# 资本—帝国主义的军事侵略（一）
#
# 1.中日甲午战争发生于哪一年?()
#
# A、1860年
#
# B、1894年
#
# C、1900年
#
# D、1936年
#
# 答案：B
#
# 2.“旅顺大屠杀惨案”的制造者是哪个国家?()
#
# A、德国
# 为什么要学习中国近现代史？
#
# 1.根据2018年版《中国近现代史纲要》,中国的近代史,是从1840年开始到()结束。
#
# A、1919年
#
# B、1937年
#
# C、1949年
#
# D、1954年
#
# 答案：C
#
# 2.树立正确的历史观,需要自觉抵制历史虚无主义。()
#
# 答案：对
#
# 准确把握《中国近现代史纲要》的教学目的与要求
#
# 1.列宁全面论述帝国主义的专著是()。
#
# A、《资本论》
#
# B、《帝国主义是资本主义的最高阶段》
#
# C、《新教伦理与资本主义精神》
#
# D、《国富论》
#
# 答案：B
#
# 2.下面属于中国特色社会主义的四个自信的是()。
#
# A、道路自信
#
# B、理论自信
#
# C、制度自信
#
# D、道德自信
#
# 答案：ABC
#
# 怎样学好中国近现代史？
#
# 1.学好中国近代史,必须要做到()。
#
# A、阅读
#
# B、思考
#
# C、讨论
#
# D、实践
#
# 答案：ABCD
#
# 2.习近平曾说,“学习的敌人是自己的满足”。()
#
# 答案：错
#
# 鸦片战争前的中国与世界
#
# 1.以下哪一项,不属于中国封建社会的基本经济特征。()
#
# A、实行高度集权的封建君主专制制度
#
# B、封建地主土地所有制占主导地位
#
# C、以个体家庭为单位并与家庭手工业牢固结合的小农经济是中国封建社会的基本生产结构
#
# D、自给自足的自然经济始终占绝对优势
#
# 答案：AD
#
# 2.在鸦片战争前,中国封建社会由昌盛到衰落。()
#
# 答案：对
#
# 外国资本主义入侵与近代中国社会的半殖民地半封建性质
#
# 1.()是中国近代史上第一个不平等条约。
#
# A、《望厦条约》
#
# B、《黄埔条约》
#
# C、《南京条约》
#
# D、《北京条约》
#
# 答案：C
#
# 2.以下哪几项,属于半殖民地半封建中国社会的特征。()
#
# A、资本-帝国主义侵略势力日益成为支配中国的决定性力量
#
# B、中国封建势力日益衰败
#
# C、中国封建剥削制度的根基在广大地区内保持着
#
# D、中国新兴民族资本主义发展缓慢、力量薄弱
#
# 答案：ABCD
#
# 近代中国的主要矛盾和历史任务
#
# 1.近代以来的历史表明,改变中国半殖民地半封建社会制度,可通过()。
#
# A、教育救国
#
# B、工业救国
#
# C、改良主义
#
# D、进行反帝反封建的民主革命
#
# 答案：D
#
# 2.近代中国半殖民地半封建社会的矛盾中,资产阶级与地主阶级的矛盾是占支配地位的主要矛盾。()
#
# 答案：错
#
# 资本—帝国主义的军事侵略（一）
#
# 1.中日甲午战争发生于哪一年?()
#
# A、1860年
#
# B、1894年
#
# C、1900年
#
# D、1936年
#
# 答案：B
#
# 2.“旅顺大屠杀惨案”的制造者是哪个国家?()
#
# A、德国
# 为什么要学习中国近现代史？
#
# 1.根据2018年版《中国近现代史纲要》,中国的近代史,是从1840年开始到()结束。
#
# A、1919年
#
# B、1937年
#
# C、1949年
#
# D、1954年
#
# 答案：C
#
# 2.树立正确的历史观,需要自觉抵制历史虚无主义。()
#
# 答案：对
#
# 准确把握《中国近现代史纲要》的教学目的与要求
#
# 1.列宁全面论述帝国主义的专著是()。
#
# A、《资本论》
#
# B、《帝国主义是资本主义的最高阶段》
#
# C、《新教伦理与资本主义精神》
#
# D、《国富论》
#
# 答案：B
#
# 2.下面属于中国特色社会主义的四个自信的是()。
#
# A、道路自信
#
# B、理论自信
#
# C、制度自信
#
# D、道德自信
#
# 答案：ABC
#
# 怎样学好中国近现代史？
#
# 1.学好中国近代史,必须要做到()。
#
# A、阅读
#
# B、思考
#
# C、讨论
#
# D、实践
#
# 答案：ABCD
#
# 2.习近平曾说,“学习的敌人是自己的满足”。()
#
# 答案：错
#
# 鸦片战争前的中国与世界
#
# 1.以下哪一项,不属于中国封建社会的基本经济特征。()
#
# A、实行高度集权的封建君主专制制度
#
# B、封建地主土地所有制占主导地位
#
# C、以个体家庭为单位并与家庭手工业牢固结合的小农经济是中国封建社会的基本生产结构
#
# D、自给自足的自然经济始终占绝对优势
#
# 答案：AD
#
# 2.在鸦片战争前,中国封建社会由昌盛到衰落。()
#
# 答案：对
#
# 外国资本主义入侵与近代中国社会的半殖民地半封建性质
#
# 1.()是中国近代史上第一个不平等条约。
#
# A、《望厦条约》
#
# B、《黄埔条约》
#
# C、《南京条约》
#
# D、《北京条约》
#
# 答案：C
#
# 2.以下哪几项,属于半殖民地半封建中国社会的特征。()
#
# A、资本-帝国主义侵略势力日益成为支配中国的决定性力量
#
# B、中国封建势力日益衰败
#
# C、中国封建剥削制度的根基在广大地区内保持着
#
# D、中国新兴民族资本主义发展缓慢、力量薄弱
#
# 答案：ABCD
#
# 近代中国的主要矛盾和历史任务
#
# 1.近代以来的历史表明,改变中国半殖民地半封建社会制度,可通过()。
#
# A、教育救国
#
# B、工业救国
#
# C、改良主义
#
# D、进行反帝反封建的民主革命
#
# 答案：D
#
# 2.近代中国半殖民地半封建社会的矛盾中,资产阶级与地主阶级的矛盾是占支配地位的主要矛盾。()
#
# 答案：错
#
# 资本—帝国主义的军事侵略（一）
#
# 1.中日甲午战争发生于哪一年?()
#
# A、1860年
#
# B、1894年
#
# C、1900年
#
# D、1936年
#
# 答案：B
#
# 2.“旅顺大屠杀惨案”的制造者是哪个国家?()
#
# A、德国
# 为什么要学习中国近现代史？
#
# 1.根据2018年版《中国近现代史纲要》,中国的近代史,是从1840年开始到()结束。
#
# A、1919年
#
# B、1937年
#
# C、1949年
#
# D、1954年
#
# 答案：C
#
# 2.树立正确的历史观,需要自觉抵制历史虚无主义。()
#
# 答案：对
#
# 准确把握《中国近现代史纲要》的教学目的与要求
#
# 1.列宁全面论述帝国主义的专著是()。
#
# A、《资本论》
#
# B、《帝国主义是资本主义的最高阶段》
#
# C、《新教伦理与资本主义精神》
#
# D、《国富论》
#
# 答案：B
#
# 2.下面属于中国特色社会主义的四个自信的是()。
#
# A、道路自信
#
# B、理论自信
#
# C、制度自信
#
# D、道德自信
#
# 答案：ABC
#
# 怎样学好中国近现代史？
#
# 1.学好中国近代史,必须要做到()。
#
# A、阅读
#
# B、思考
#
# C、讨论
#
# D、实践
#
# 答案：ABCD
#
# 2.习近平曾说,“学习的敌人是自己的满足”。()
#
# 答案：错
#
# 鸦片战争前的中国与世界
#
# 1.以下哪一项,不属于中国封建社会的基本经济特征。()
#
# A、实行高度集权的封建君主专制制度
#
# B、封建地主土地所有制占主导地位
#
# C、以个体家庭为单位并与家庭手工业牢固结合的小农经济是中国封建社会的基本生产结构
#
# D、自给自足的自然经济始终占绝对优势
#
# 答案：AD
#
# 2.在鸦片战争前,中国封建社会由昌盛到衰落。()
#
# 答案：对
#
# 外国资本主义入侵与近代中国社会的半殖民地半封建性质
#
# 1.()是中国近代史上第一个不平等条约。
#
# A、《望厦条约》
#
# B、《黄埔条约》
#
# C、《南京条约》
#
# D、《北京条约》
#
# 答案：C
#
# 2.以下哪几项,属于半殖民地半封建中国社会的特征。()
#
# A、资本-帝国主义侵略势力日益成为支配中国的决定性力量
#
# B、中国封建势力日益衰败
#
# C、中国封建剥削制度的根基在广大地区内保持着
#
# D、中国新兴民族资本主义发展缓慢、力量薄弱
#
# 答案：ABCD
#
# 近代中国的主要矛盾和历史任务
#
# 1.近代以来的历史表明,改变中国半殖民地半封建社会制度,可通过()。
#
# A、教育救国
#
# B、工业救国
#
# C、改良主义
#
# D、进行反帝反封建的民主革命
#
# 答案：D
#
# 2.近代中国半殖民地半封建社会的矛盾中,资产阶级与地主阶级的矛盾是占支配地位的主要矛盾。()
#
# 答案：错
#
# 资本—帝国主义的军事侵略（一）
#
# 1.中日甲午战争发生于哪一年?()
#
# A、1860年
#
# B、1894年
#
# C、1900年
#
# D、1936年
#
# 答案：B
#
# 2.“旅顺大屠杀惨案”的制造者是哪个国家?()
#
# A、德国
